# %% [markdown]
# <a href="https://colab.research.google.com/github/GIGAParviz/Hnad-Sign-Detector/blob/main/Hand_Sign(YOLO_8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 ! pip install -q kaggle

from google.colab import files

files.upload()
! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-0e5770d7-98c3-4f0d-abc4-f385627b2266" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e5770d7-98c3-4f0d-abc4-f385627b2266">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets download -d daskoushik/sign-language-dataset-for-yolov7
# Out:
# ...
#  61% 25.0M/40.7M [00:00<00:00, 58.1MB/s]
# 100% 40.7M/40.7M [00:00<00:00, 75.2MB/s]

# %%
# !unzip sign-language-dataset-for-yolov7 -d signl
# Out:
# Archive:  sign-language-dataset-for-yolov7.zip
#   inflating: signl/README.dataset.txt
#   inflating: signl/README.roboflow.txt
#   inflating: signl/data.yaml
#   inflating: signl/test/images/A22_jpg.rf.2584deaa261bba945ec5beb1436bed69.jpg
#   inflating: signl/test/images/B14_jpg.rf.316f9f7c75f7bde778f57c62602288cc.jpg
#   inflating: signl/test/images/B15_jpg.rf.c22d3240fe243dc747817258ca688e7c.jpg
#   inflating: signl/test/images/B19_jpg.rf.708eb6eafd7ab93013935840ac157c49.jpg
#   inflating: signl/test/images/C17_jpg.rf.1b0d39a35f3b5221c0de9e17f17a83da.jpg
#   inflating: signl/test/images/C19_jpg.rf.0add6365e398b8d188f428bac97eb868.jpg
#   inflating: signl/test/images/C22_jpg.rf.e4b7a26b760419387cdad00b2f900af2.jpg
#   inflating: signl/test/images/C23_jpg.rf.0fce204eb540b1020388c210718c2e1c.jpg
#   inflating: signl/test/images/D1_jpg.rf.19ba04ebac843971a378abfdb27e787d.jpg
#   inflating: signl/test/images/F17_jpg.rf.31a75048a5992d4f1e829a8c288c3389.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.3/645.3 kB 7.5 MB/s eta 0:00:00
# ...

# %%
import ultralytics
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# !yolo task=detect mode=train model=yolov8m data='/content/signl/data.yaml' epochs=100 imgsz=256
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image

# %%
Image('/content/runs/detect/train3/F1_curve.png'  , width=800 , height=800)

# %%
Image('/content/runs/detect/train3/PR_curve.png'  , width=800 , height=800)

# %%
Image('/content/runs/detect/train3/P_curve.png'  , width=800 , height=800)

# %%
Image('/content/runs/detect/train3/R_curve.png'  , width=800 , height=800)

# %%
Image('/content/runs/detect/train3/confusion_matrix.png'  , width=800 , height=800)

# %%
Image('/content/runs/detect/train3/confusion_matrix_normalized.png'  , width=800 , height=800)

# %%
Image('/content/runs/detect/train3/confusion_matrix_normalized.png'  , width=800 , height=800)

# %%
Image('/content/runs/detect/train3/results.png')

# %%
Image('/content/runs/detect/train3/labels.jpg'  , width=800 , height=800)

# %%
print('labels')
Image('/content/runs/detect/train3/val_batch2_labels.jpg'  , width=800 , height=800)
# Out:
# labels

# %%
print('prediction')
Image('/content/runs/detect/train3/val_batch2_pred.jpg'  , width=800 , height=800)
# Out:
# prediction

# %%
# !yolo task=detect mode=predict source='/content/signl/test/images' model=/content/runs/detect/train3/weights/best.pt
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25854814 parameters, 0 gradients, 78.8 GFLOPs
#
# image 1/72 /content/signl/test/images/A22_jpg.rf.2584deaa261bba945ec5beb1436bed69.jpg: 256x256 1 A, 19.0ms
# image 2/72 /content/signl/test/images/B14_jpg.rf.316f9f7c75f7bde778f57c62602288cc.jpg: 256x256 1 B, 29.7ms
# image 3/72 /content/signl/test/images/B15_jpg.rf.c22d3240fe243dc747817258ca688e7c.jpg: 256x256 1 B, 24.1ms
# image 4/72 /content/signl/test/images/B19_jpg.rf.708eb6eafd7ab93013935840ac157c49.jpg: 256x256 1 B, 18.5ms
# image 5/72 /content/signl/test/images/C17_jpg.rf.1b0d39a35f3b5221c0de9e17f17a83da.jpg: 256x256 1 C, 12.7ms
# image 6/72 /content/signl/test/images/C19_jpg.rf.0add6365e398b8d188f428bac97eb868.jpg: 256x256 1 C, 12.7ms
# image 7/72 /content/signl/test/images/C22_jpg.rf.e4b7a26b760419387cdad00b2f900af2.jpg: 256x256 1 C, 12.7ms
# ...
