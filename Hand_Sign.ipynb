# %% [markdown]
# <a href="https://colab.research.google.com/github/GIGAParviz/Hnad-Sign-Detector/blob/main/Hand_Sign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.0/646.0 kB 9.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="1la9l1qdFhzEOIJR00Z6")
project = rf.workspace("elainesilva").project("alfabeto-em-libras-qrvnw")
dataset = project.version(6).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
import ultralytics

# %%
# !yolo task=detect mode=train model='yolov8m' data='/content/Alfabeto-em-libras-6/data.yaml' epochs=100
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 238MB/s]
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image

# %%
Image('/content/runs/detect/train/F1_curve.png')

# %%
Image('/content/runs/detect/train/PR_curve.png')

# %%
Image('/content/runs/detect/train/P_curve.png')

# %%
Image('/content/runs/detect/train/R_curve.png')

# %%
Image('/content/runs/detect/train/confusion_matrix.png')

# %%
Image('/content/runs/detect/train/labels_correlogram.jpg')

# %%
Image('/content/runs/detect/train/results.png')

# %%
Image('/content/runs/detect/train/val_batch1_pred.jpg')
